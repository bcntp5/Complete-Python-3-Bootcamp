# %% [markdown]
# <a href="https://colab.research.google.com/github/bcntp5/Complete-Python-3-Bootcamp/blob/master/IT7103_Assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  Questions 1-10

# %% [markdown]
# # 1. (1 pt) Create a Jupyter Notebook and load the provided dataset into a pandas DataFrame.

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

import pandas as pd

data = pd.read_csv('/content/drive/MyDrive/IT7103/employee_dataset.csv')
data
# Out:
# Mounted at /content/drive
#         employee_id   first_name   last_name  \
# 0          EMP93810     Danielle     Johnson
# 1          EMP38657        Helen    Peterson
# 2          EMP30926        Donna       Mejia
# 3          EMP44671        Linda     Morales
# 4          EMP16006  Christopher    Williams
# ...             ...          ...         ...
# 3999995    EMP34532       Edward        Cook
# 3999996    EMP54893      Jessica      Wilson
# 3999997    EMP75190          Amy    Williams
# 3999998    EMP54734        David  Stephenson
# 3999999    EMP24609     Jennifer    Thompson
#
#                                      email            phone_number  \
# 0            danielle.johnson@company.com@        533-521-8196x001
# 1              helen.peterson@company.com@           (635)211-6155
# 2                 donna.mejia@company.com@            731-564-7525
# 3               linda.morales@company.com@            639-453-7672
# ...

# %%
data.dtypes
# Out:
# employee_id                  object
# first_name                   object
# last_name                    object
# email                        object
# phone_number                 object
# hire_date                    object
# department                   object
# position                     object
# salary                        int64
# manager_id                   object
# office_location              object
# employment_status            object
# performance_rating           object
# years_experience            float64
# education_level              object
# certification_count           int64
# training_hours_completed      int64
# last_performance_review      object
# emergency_contact_phone      object
# home_location                object
# notes                        object
# dtype: object

# %% [markdown]
# #2. (1 pt) Determine how many instances (rows) and features (columns) the dataset contains. Write code to display
# this information, and provide your answers.

# %% [markdown]
# I could also just call 'data' and it will tell me the rows and columns

# %%
data
# Out:
#         employee_id   first_name   last_name  \
# 0          EMP93810     Danielle     Johnson
# 1          EMP38657        Helen    Peterson
# 2          EMP30926        Donna       Mejia
# 3          EMP44671        Linda     Morales
# 4          EMP16006  Christopher    Williams
# ...             ...          ...         ...
# 3999995    EMP34532       Edward        Cook
# 3999996    EMP54893      Jessica      Wilson
# 3999997    EMP75190          Amy    Williams
# 3999998    EMP54734        David  Stephenson
# 3999999    EMP24609     Jennifer    Thompson
#
#                                      email            phone_number  \
# 0            danielle.johnson@company.com@        533-521-8196x001
# 1              helen.peterson@company.com@           (635)211-6155
# 2                 donna.mejia@company.com@            731-564-7525
# 3               linda.morales@company.com@            639-453-7672
# 4        christopher.williams@company.com@            922-669-1669
# ...

# %%
# Number of Rows

print(data.shape[0])
# Out:
# 4000000

# %%
# Number of Columns

print(data.shape[1])
# Out:
# 21

# %% [markdown]
# 3. (1 pt) Generate histograms for all numeric feature columns in the dataset.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # In this one I ask for help from Gemini, but I did not copy an paste.
# # I also used youtube as well:
# # Please see the video below at minute number 4:11/5:45.
#
# https://www.youtube.com/watch?v=zNvxJNQhmRs&t=5s

# %%
# In this one I ask for help from Gemini.
# I did not copy an paste though.
# I also used youtube as well:

import matplotlib.pyplot as plt

#Create larger space so words dont run together.
plt.figure(figsize=(15,10))

#Histogram Gereration
data.hist(column=['years_experience','certification_count', 'training_hours_completed' ])

#This adjusted the subplot parameters for tight layout
plt.tight_layout()

#Display the plot
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# 4. (1 pt) Based on the histograms from Q3, identify the feature that is the most strongly right-skewed.

# %%
data.hist(column= 'training_hours_completed')
# Out:
# array([[<Axes: title={'center': 'training_hours_completed'}>]],
#       dtype=object)

# %% [markdown]
# 5. (2 pts) Transform the skewed feature using NumPy’s log1p function. Plot its updated histogram again, and discuss
# the outcome. Why does applying a logarithmic transformation produce this result?

# %% [markdown]
# # This is the youtube video and the website that I used for this one.
# 1. https://datascience.stackexchange.com/questions/14216/transform-a-skewed-distribution-into-a-gaussian-distribution
#
# 2. https://www.youtube.com/watch?v=ngBxYo6FQiI

# %% [markdown]
# I searched high and low. I am currently using Gemini to help me figure this one out.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# I searched high and low. I am currently using Gemini to help me figure this one out.

# %%
#1. Generate Right skewed data
training_hours_completed = np.random.exponential(scale=10, size=1000)

#2. apply log1p transformation to normalize the distrubution
transformed_data = np.log1p(training_hours_completed)

#3. Plot the before and after histograms
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# Plot the original skewed data on the first subplot (axes[0])
axes[0].hist(training_hours_completed, bins=30, color='blue', edgecolor='black')
axes[0].set_title('Original Right-Skewed Data')
axes[0].set_xlabel('Training Hours Completed')
axes[0].set_ylabel('Frequency')

# Loglp1p Transformed Historgram

axes[1].hist(transformed_data, bins=30, color= 'green', edgecolor= 'black')
axes[1].set_title('Log1p Transformed Data')
axes[1].set_xlabel('Log1p(Training Hours Completed)')
axes[1].set_ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# As the numbers get bigger the logramic scale slower due to the exponents. Applying the lp pulls the outside numbers back toward the center. For near 0 the transformation stretches the spacing. This is away to keep the data clean and the numbers close to zero with out messing up he plotted numbers.

# %% [markdown]
# 6. (2 pts) Examine the dataset and identify three features that contain unreasonable or problematic values. Print out
# the data for each feature, and explain the issues you observe.

# %%
data
# Out:
#         employee_id   first_name   last_name  \
# 0          EMP93810     Danielle     Johnson
# 1          EMP38657        Helen    Peterson
# 2          EMP30926        Donna       Mejia
# 3          EMP44671        Linda     Morales
# 4          EMP16006  Christopher    Williams
# ...             ...          ...         ...
# 3999995    EMP34532       Edward        Cook
# 3999996    EMP54893      Jessica      Wilson
# 3999997    EMP75190          Amy    Williams
# 3999998    EMP54734        David  Stephenson
# 3999999    EMP24609     Jennifer    Thompson
#
#                                      email            phone_number  \
# 0            danielle.johnson@company.com@        533-521-8196x001
# 1              helen.peterson@company.com@           (635)211-6155
# 2                 donna.mejia@company.com@            731-564-7525
# 3               linda.morales@company.com@            639-453-7672
# 4        christopher.williams@company.com@            922-669-1669
# ...

# %%
data['emergency_contact_phone'] # This column has a lot of added numbers and letter that it does not need.
# Out:
# 0                     2834863794
# 1                   361-284-9593
# 2          +1-519-228-3276x48350
# 3                +1-484-996-9653
# 4                     9182451462
#                    ...
# 3999995             947-927-9167
# 3999996             924.524.9498
# 3999997     001-732-851-1515x171
# 3999998             360.277.1028
# 3999999               2937564554
# Name: emergency_contact_phone, Length: 4000000, dtype: object

# %%
data['hire_date'] # This one shoul dbe in a two-digit month-date-year format.
# Out:
# 0          2024-04-24
# 1          2023-07-13
# 2          2020-04-03
# 3          2019-11-29
# 4          2025-02-15
#               ...
# 3999995    2021-04-09
# 3999996    2019-06-09
# 3999997    2016-07-04
# 3999998    2020-02-25
# 3999999    2025-04-18
# Name: hire_date, Length: 4000000, dtype: object

# %%
data['email']# This one has too many @ symbols.
# Out:
# 0              danielle.johnson@company.com@
# 1                helen.peterson@company.com@
# 2                   donna.mejia@company.com@
# 3                 linda.morales@company.com@
# 4          christopher.williams@company.com@
#                          ...
# 3999995             edward.cook@company.com@
# 3999996          jessica.wilson@company.com@
# 3999997            amy.williams@company.com@
# 3999998        david.stephenson@company.com@
# 3999999       jennifer.thompson@company.com@
# Name: email, Length: 4000000, dtype: object

# %%
data['last_performance_review']# This one I feel like it should be in a two-digit month-date-year format.
# Out:
# 0          2025-05-07
# 1          2025-04-12
# 2          2025-06-15
# 3          2025-07-02
# 4          2025-08-16
#               ...
# 3999995    2025-04-22
# 3999996    2025-07-15
# 3999997    2025-07-04
# 3999998    2025-06-12
# 3999999    2025-04-27
# Name: last_performance_review, Length: 4000000, dtype: object

# %% [markdown]
# 7. (1 pt) Fix the issues identified in Q6, and display the updated DataFrame to confirm the corrections.

# %%
data.dtypes
# Out:
# employee_id                  object
# first_name                   object
# last_name                    object
# email                        object
# phone_number                 object
# hire_date                    object
# department                   object
# position                     object
# salary                        int64
# manager_id                   object
# office_location              object
# employment_status            object
# performance_rating           object
# years_experience            float64
# education_level              object
# certification_count           int64
# training_hours_completed      int64
# last_performance_review      object
# emergency_contact_phone      object
# home_location                object
# notes                        object
# dtype: object

# %% [markdown]
# I did ask gemini for help on this one to choose the method of the regex expression. I did not think of all of this myself. But I am still going to practice because I want to be good enough to memorize how to do them without any help.

# %%
#Feature 1 - Removing @ symbols with regex expression
data['email']= data['email'].str.replace(r"^([^@]*@[^@]*)@", r"\1", regex=True)

# %%
data['email']
# Out:
# 0              danielle.johnson@company.com
# 1                helen.peterson@company.com
# 2                   donna.mejia@company.com
# 3                 linda.morales@company.com
# 4          christopher.williams@company.com
#                          ...
# 3999995             edward.cook@company.com
# 3999996          jessica.wilson@company.com
# 3999997            amy.williams@company.com
# 3999998        david.stephenson@company.com
# 3999999       jennifer.thompson@company.com
# Name: email, Length: 4000000, dtype: object

# %%
data['hire_date'] # old column
# Out:
# 0          2024-04-24
# 1          2023-07-13
# 2          2020-04-03
# 3          2019-11-29
# 4          2025-02-15
#               ...
# 3999995    2021-04-09
# 3999996    2019-06-09
# 3999997    2016-07-04
# 3999998    2020-02-25
# 3999999    2025-04-18
# Name: hire_date, Length: 4000000, dtype: object

# %% [markdown]
# Here is the link to the video I used for this problem: https://www.youtube.com/watch?v=f7LODKIjtaA

# %%
#Feature 2 - Change date from an object to a datetime format.
data['hire_date'] = pd.to_datetime(data['hire_date'])

# %%
data['hire_date']# new column
# Out:
# 0         2024-04-24
# 1         2023-07-13
# 2         2020-04-03
# 3         2019-11-29
# 4         2025-02-15
#              ...
# 3999995   2021-04-09
# 3999996   2019-06-09
# 3999997   2016-07-04
# 3999998   2020-02-25
# 3999999   2025-04-18
# Name: hire_date, Length: 4000000, dtype: datetime64[ns]

# %%
#Feature 2 - Change date from an object to a datetime format. (same here)
data['last_performance_review'] = pd.to_datetime(data['last_performance_review'])

data['last_performance_review'] # update column
# Out:
# 0         2025-05-07
# 1         2025-04-12
# 2         2025-06-15
# 3         2025-07-02
# 4         2025-08-16
#              ...
# 3999995   2025-04-22
# 3999996   2025-07-15
# 3999997   2025-07-04
# 3999998   2025-06-12
# 3999999   2025-04-27
# Name: last_performance_review, Length: 4000000, dtype: datetime64[ns]

# %% [markdown]
# So this video helped me out tremendously with 90% if of this question. I prompted Gemini for a tiny piece. On this quesion I mainly used this video and some gemini.
#
# https://www.youtube.com/watch?v=bDhvCp3_lYw&t=42s

# %%
data['emergency_contact_phone']
# Out:
# 0                     2834863794
# 1                   361-284-9593
# 2          +1-519-228-3276x48350
# 3                +1-484-996-9653
# 4                     9182451462
#                    ...
# 3999995             947-927-9167
# 3999996             924.524.9498
# 3999997     001-732-851-1515x171
# 3999998             360.277.1028
# 3999999               2937564554
# Name: emergency_contact_phone, Length: 4000000, dtype: object

# %%
data['emergency_contact_phone'] = data['emergency_contact_phone'].str.replace('[^a-zA-Z0-9]', '', regex=True)

data['emergency_contact_phone']
# Out:
# 0                 2834863794
# 1                 3612849593
# 2          15192283276x48350
# 3                14849969653
# 4                 9182451462
#                  ...
# 3999995           9479279167
# 3999996           9245249498
# 3999997    0017328511515x171
# 3999998           3602771028
# 3999999           2937564554
# Name: emergency_contact_phone, Length: 4000000, dtype: object

# %%
data['emergency_contact_phone'] = data['emergency_contact_phone'].apply(lambda x: x[0:3] + '-' + x[3:6] + '-' + x[6:10])

data
# Out:
#         employee_id   first_name   last_name  \
# 0          EMP93810     Danielle     Johnson
# 1          EMP38657        Helen    Peterson
# 2          EMP30926        Donna       Mejia
# 3          EMP44671        Linda     Morales
# 4          EMP16006  Christopher    Williams
# ...             ...          ...         ...
# 3999995    EMP34532       Edward        Cook
# 3999996    EMP54893      Jessica      Wilson
# 3999997    EMP75190          Amy    Williams
# 3999998    EMP54734        David  Stephenson
# 3999999    EMP24609     Jennifer    Thompson
#
#                                     email            phone_number  hire_date  \
# 0            danielle.johnson@company.com        533-521-8196x001 2024-04-24
# 1              helen.peterson@company.com           (635)211-6155 2023-07-13
# 2                 donna.mejia@company.com            731-564-7525 2020-04-03
# 3               linda.morales@company.com            639-453-7672 2019-11-29
# ...

# %%
data['phone_number'] = data['phone_number'].str.replace('[^a-zA-Z0-9]', '', regex=True)

data['phone_number']
# Out:
# 0               5335218196x001
# 1                   6352116155
# 2                   7315647525
# 3                   6394537672
# 4                   9226691669
#                   ...
# 3999995       7593405564x08109
# 3999996    0012767290664x68202
# 3999997             9884019160
# 3999998             8293530139
# 3999999       2962385907x38510
# Name: phone_number, Length: 4000000, dtype: object

# %%
data['phone_number'] = data['phone_number'].apply(lambda x: x[0:3] + '-' + x[3:6] + '-' + x[6:10])

data
# Out:
#         employee_id   first_name   last_name  \
# 0          EMP93810     Danielle     Johnson
# 1          EMP38657        Helen    Peterson
# 2          EMP30926        Donna       Mejia
# 3          EMP44671        Linda     Morales
# 4          EMP16006  Christopher    Williams
# ...             ...          ...         ...
# 3999995    EMP34532       Edward        Cook
# 3999996    EMP54893      Jessica      Wilson
# 3999997    EMP75190          Amy    Williams
# 3999998    EMP54734        David  Stephenson
# 3999999    EMP24609     Jennifer    Thompson
#
#                                     email  phone_number  hire_date  \
# 0            danielle.johnson@company.com  533-521-8196 2024-04-24
# 1              helen.peterson@company.com  635-211-6155 2023-07-13
# 2                 donna.mejia@company.com  731-564-7525 2020-04-03
# 3               linda.morales@company.com  639-453-7672 2019-11-29
# 4        christopher.williams@company.com  922-669-1669 2025-02-15
# ...

# %% [markdown]
# 8. (1 pt) Select one categorical feature that has an ordinal nature. Convert it into a numeric feature by mapping its
# values to meaningful integers using the pattern: df["column"] = df["column"].map(mapping). Visualize the
# histogram of the updated column.

# %% [markdown]
# Here is the YouTube video I used for this. https://www.youtube.com/watch?v=GMrK9Hdkr7Q

# %%
data['performance_rating'].unique()
# Out:
# array(['Exceeds Expectations', 'Meets Expectations', 'Outstanding',
#        'Below Expectations', 'Needs Improvement'], dtype=object)

# %%
data['performance_rating']
# Out:
# 0          Exceeds Expectations
# 1            Meets Expectations
# 2                   Outstanding
# 3            Below Expectations
# 4                   Outstanding
#                    ...
# 3999995       Needs Improvement
# 3999996             Outstanding
# 3999997      Meets Expectations
# 3999998    Exceeds Expectations
# 3999999    Exceeds Expectations
# Name: performance_rating, Length: 4000000, dtype: object

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
data['performance_rating'].unique()
# Out:
# array(['Exceeds Expectations', 'Meets Expectations', 'Outstanding',
#        'Below Expectations', 'Needs Improvement'], dtype=object)

# %%
enc = OrdinalEncoder()

enc.fit(data[['performance_rating']])

data['New_Column'] = enc.transform(data[['performance_rating']])

# %%
data.head()
# Out:
#   employee_id   first_name last_name                             email  \
# 0    EMP93810     Danielle   Johnson      danielle.johnson@company.com
# 1    EMP38657        Helen  Peterson        helen.peterson@company.com
# 2    EMP30926        Donna     Mejia           donna.mejia@company.com
# 3    EMP44671        Linda   Morales         linda.morales@company.com
# 4    EMP16006  Christopher  Williams  christopher.williams@company.com
#
#    phone_number  hire_date       department                  position  salary  \
# 0  533-521-8196 2024-04-24  Human Resources             HR Generalist  117000
# 1  635-211-6155 2023-07-13       IT Support      Help Desk Specialist   92000
# 2  731-564-7525 2020-04-03      Procurement      Supply Chain Analyst   65000
# 3  639-453-7672 2019-11-29            Sales  Business Development Rep   78000
# 4  922-669-1669 2025-02-15       IT Support          Network Engineer   66000
#
# ...

# %%
data.drop('New_column',axis=1)
# Out:
#         employee_id   first_name   last_name  \
# 0          EMP93810     Danielle     Johnson
# 1          EMP38657        Helen    Peterson
# 2          EMP30926        Donna       Mejia
# 3          EMP44671        Linda     Morales
# 4          EMP16006  Christopher    Williams
# ...             ...          ...         ...
# 3999995    EMP34532       Edward        Cook
# 3999996    EMP54893      Jessica      Wilson
# 3999997    EMP75190          Amy    Williams
# 3999998    EMP54734        David  Stephenson
# 3999999    EMP24609     Jennifer    Thompson
#
#                                     email  phone_number  hire_date  \
# 0            danielle.johnson@company.com  533-521-8196 2024-04-24
# 1              helen.peterson@company.com  635-211-6155 2023-07-13
# 2                 donna.mejia@company.com  731-564-7525 2020-04-03
# 3               linda.morales@company.com  639-453-7672 2019-11-29
# 4        christopher.williams@company.com  922-669-1669 2025-02-15
# ...

# %%
enc = OrdinalEncoder(categories=[['Below Expectations', 'Needs Improvement', 'Meets Expectations', 'Exceeds Expectations', 'Outstanding']])

data['New_Column'] = enc.fit_transform(data[['performance_rating']])
data.head()
# Out:
#   employee_id   first_name last_name                             email  \
# 0    EMP93810     Danielle   Johnson      danielle.johnson@company.com
# 1    EMP38657        Helen  Peterson        helen.peterson@company.com
# 2    EMP30926        Donna     Mejia           donna.mejia@company.com
# 3    EMP44671        Linda   Morales         linda.morales@company.com
# 4    EMP16006  Christopher  Williams  christopher.williams@company.com
#
#    phone_number  hire_date       department                  position  salary  \
# 0  533-521-8196 2024-04-24  Human Resources             HR Generalist  117000
# 1  635-211-6155 2023-07-13       IT Support      Help Desk Specialist   92000
# 2  731-564-7525 2020-04-03      Procurement      Supply Chain Analyst   65000
# 3  639-453-7672 2019-11-29            Sales  Business Development Rep   78000
# 4  922-669-1669 2025-02-15       IT Support          Network Engineer   66000
#
# ...

# %%
data.drop('New_column', axis=1)
# Out:
#         employee_id   first_name   last_name  \
# 0          EMP93810     Danielle     Johnson
# 1          EMP38657        Helen    Peterson
# 2          EMP30926        Donna       Mejia
# 3          EMP44671        Linda     Morales
# 4          EMP16006  Christopher    Williams
# ...             ...          ...         ...
# 3999995    EMP34532       Edward        Cook
# 3999996    EMP54893      Jessica      Wilson
# 3999997    EMP75190          Amy    Williams
# 3999998    EMP54734        David  Stephenson
# 3999999    EMP24609     Jennifer    Thompson
#
#                                     email  phone_number  hire_date  \
# 0            danielle.johnson@company.com  533-521-8196 2024-04-24
# 1              helen.peterson@company.com  635-211-6155 2023-07-13
# 2                 donna.mejia@company.com  731-564-7525 2020-04-03
# 3               linda.morales@company.com  639-453-7672 2019-11-29
# 4        christopher.williams@company.com  922-669-1669 2025-02-15
# ...

# %% [markdown]
# I did get help from Gemini on this part. But, I did not do any copying pasting. I try to make sure I type every thing out. I am really trying to find insight on how to commit this to my memory. The only way I know is constant repetition. Any insight that you can give I would be above and beyond open to trying. I would be greatful.

# %%
mapping = {'Below Expectations': 1,
            'Needs Improvement': 2,
            'Meets Expectations': 3,
            'Exceeds Expectations': 4,
            'Outstanding':5}

data['performance_rating'] = data['performance_rating'].map(mapping)

# %%
import matplotlib.pyplot as plt

# %%
data['performance_rating'].plot(kind='hist', bins=3, edgecolor='black')
plt.title('Histogram of Performance Ratings Satisfaction Level')
plt.xlabel('Satisfaction Level (Encoded)')
plt.ylabel('Count')
plt.show()
